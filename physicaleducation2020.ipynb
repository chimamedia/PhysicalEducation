# %% [markdown]
# <a href="https://colab.research.google.com/github/chimamedia/PhysicalEducation/blob/master/physicaleducation2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Google Driveを接続する。
# - この操作は、開始時に必ず行うこと。

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # プログラムを起動するために、操作する

# %%
cd /content/drive/My\ Drive/Colab\ Notebooks
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
# !git clone https://github.com/chimamedia/PhysicalEducation.git
# Out:
# fatal: destination path 'PhysicalEducation' already exists and is not an empty directory.

# %%
cd PhysicalEducation/
# Out:
# /content/drive/My Drive/Colab Notebooks/PhysicalEducation

# %% [markdown]
# #次のプログラムは初めてやった場合のみ実行する
# - セットアップになるため、ネットワークのある場所で行うこと

# %%
cd models/
# Out:
# [Errno 2] No such file or directory: 'model/'
# /content/drive/My Drive/Colab Notebooks/PhysicalEducation

# %%
# !wget http://posefs1.perception.cs.cmu.edu/OpenPose/models/pose/coco/pose_iter_440000.caffemodel
# !wget http://posefs1.perception.cs.cmu.edu/OpenPose/models/face/pose_iter_116000.caffemodel
# !wget http://posefs1.perception.cs.cmu.edu/OpenPose/models/hand/pose_iter_102000.caffemodel
# !python convert_model.py posenet pose_iter_440000.caffemodel coco_posenet.npz
# !python convert_model.py facenet pose_iter_116000.caffemodel facenet.npz
# !python convert_model.py handnet pose_iter_102000.caffemodel handnet.npz
# Out:
# --2020-10-28 15:38:19--  http://posefs1.perception.cs.cmu.edu/OpenPose/models/pose/coco/pose_iter_440000.caffemodel
# Resolving posefs1.perception.cs.cmu.edu (posefs1.perception.cs.cmu.edu)... 128.2.176.37
# Connecting to posefs1.perception.cs.cmu.edu (posefs1.perception.cs.cmu.edu)|128.2.176.37|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 209274056 (200M) [text/plain]
# Saving to: ‘pose_iter_440000.caffemodel’
#
# pose_iter_440000.ca 100%[===================>] 199.58M  39.0MB/s    in 7.3s
#
# 2020-10-28 15:38:27 (27.4 MB/s) - ‘pose_iter_440000.caffemodel’ saved [209274056/209274056]
#
# --2020-10-28 15:38:27--  http://posefs1.perception.cs.cmu.edu/OpenPose/models/face/pose_iter_116000.caffemodel
# Resolving posefs1.perception.cs.cmu.edu (posefs1.perception.cs.cmu.edu)... 128.2.176.37
# Connecting to posefs1.perception.cs.cmu.edu (posefs1.perception.cs.cmu.edu)|128.2.176.37|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
cd ..
# Out:
# /content/drive/My Drive/Colab Notebooks

# %% [markdown]
# # サンプル動画で実行する

# %%
# !python physicaledu_mat.py --video zenten_ok01.mp4 --gpu 0 --out result_zentenok01
# Out:
# draw point: ALL
# Loading the model...
#   0% 0/145.0 [00:00<?, ?it/s]/content/drive/My Drive/Colab Notebooks/PhysicalEducation/pose_detector.py:147: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   paf_in_edge = np.hstack([paf[0][np.hsplit(integ_points, 2)], paf[1][np.hsplit(integ_points, 2)]])
# 100% 145/145.0 [00:35<00:00,  5.62it/s]Failed to capture image
# 100% 145/145.0 [00:35<00:00,  4.04it/s]

# %% [markdown]
# # サンプルの結果を確認したい場合は実行
# - !ffmpeg -i XXX.avi -vcodec vp9 out_zenten.webm
# -- 「XXX」を--out の後ろの文字にする

# %%
# !ffmpeg -i result_zentenok01_skeleton-view.avi -vcodec vp9 result_zentenok01.webm
# Out:
# ffmpeg version 3.4.8-0ubuntu0.2 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
# ...

# %%
from IPython.display import HTML
import base64
import io

def play(file_path):
    video = io.open(file_path, 'r+b').read()
    encoded = base64.b64encode(video)
    return(HTML(data='''<video width="320" height="240" controls><source src="data:video/mp4;base64,{0}" type="video/mp4" /></video>'''.format(encoded.decode('ascii'))))

play('./result_zentenok01.webm')
# Out:
# <video width="320" height="240" controls><source src="data:video/mp4;base64,..." type="video/mp4" /></video>

# %% [markdown]
# # ビデオをダウンロードしたい場合

# %%
from google.colab import files
files.download('result_zentenok01_skeleton-view.avi')

# %% [markdown]
# # ビデオをアップロードする
# - アップロードするときは、インターネットの接続が必要になります。
# - 少し時間がかかります。

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4101a9c2-2796-484a-9423-07d15164057f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4101a9c2-2796-484a-9423-07d15164057f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kouten_ok01.mp4 to kouten_ok01.mp4

# %% [markdown]
# # アップロードされたビデオでプログラムを実行する

# %%
# !python physicaledu_mat.py --video [ファイル名に変える].mp4 --gpu 0 --out result_[ファイル名に変える]

# %%
from google.colab import files
files.download('[ファイル名に変える]_skeleton-view.avi')
